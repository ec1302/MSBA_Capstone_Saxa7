# %%
import pandas as pd

# %%
# Reading the data into a data frame
df = pd.read_csv('year_2019.csv')

# %%
print(df.columns)
print(len(df.columns))
# Out:
# Index(['activity_year', 'lei', 'derived_msa-md', 'state_code', 'county_code',
#        'census_tract', 'conforming_loan_limit', 'derived_loan_product_type',
#        'derived_dwelling_category', 'derived_ethnicity', 'derived_race',
#        'derived_sex', 'action_taken', 'purchaser_type', 'preapproval',
#        'loan_type', 'loan_purpose', 'lien_status', 'reverse_mortgage',
#        'open-end_line_of_credit', 'business_or_commercial_purpose',
#        'loan_amount', 'loan_to_value_ratio', 'interest_rate', 'rate_spread',
#        'hoepa_status', 'total_loan_costs', 'total_points_and_fees',
#        'origination_charges', 'discount_points', 'lender_credits', 'loan_term',
#        'prepayment_penalty_term', 'intro_rate_period', 'negative_amortization',
#        'interest_only_payment', 'balloon_payment',
#        'other_nonamortizing_features', 'property_value', 'construction_method',
#        'occupancy_type', 'manufactured_home_secured_property_type',
# ...

# %%
print(df.shape)
df.head(10)
# Out:
# (17573984, 99)
#    activity_year                   lei  derived_msa-md state_code  \
# 0           2019  549300BX448ALT10FI43           41180         MO
# 1           2019  549300BX448ALT10FI43           39540         WI
# 2           2019  549300BX448ALT10FI43           37860         FL
# 3           2019  549300BX448ALT10FI43           99999         KY
# 4           2019  549300BX448ALT10FI43           49340         MA
# 5           2019  549300BX448ALT10FI43           49420         WA
# 6           2019  549300BX448ALT10FI43           40900         CA
# 7           2019  549300BX448ALT10FI43           27140         MS
# 8           2019  549300BX448ALT10FI43           24300         CO
# 9           2019  549300BX448ALT10FI43           99999         MN
#
#    county_code   census_tract conforming_loan_limit derived_loan_product_type  \
# 0      29099.0  29099701000.0                     C             VA:First Lien
# ...

# %%
corr_matrix = df.corr()
# Out:
# C:\Users\Emerson\AppData\Local\Temp\ipykernel_17748\3147368345.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
ethnicity_corr = corr_matrix['applicant_ethnicity-1']
ethnicity_corr = ethnicity_corr.sort_values(ascending=False)
print(ethnicity_corr.head(15))
# Out:
# applicant_ethnicity-1           1.000000
# co-applicant_ethnicity-5        0.895266
# applicant_ethnicity-5           0.568901
# applicant_sex                   0.453300
# co-applicant_ethnicity-4        0.436460
# applicant_race_observed         0.335546
# applicant_ethnicity_observed    0.335381
# applicant_sex_observed          0.332810
# action_taken                    0.242907
# applicant_race-1                0.212066
# co-applicant_ethnicity-1        0.181948
# aus-3                           0.103353
# denial_reason-1                 0.094700
# co-applicant_race-4             0.082986
# co-applicant_race-1             0.071242
# Name: applicant_ethnicity-1, dtype: float64

# %%
race_corr = corr_matrix['applicant_race-1']
race_corr = race_corr.sort_values(ascending=False)
print(ethnicity_corr.head(15))
# Out:
# applicant_ethnicity-1           1.000000
# co-applicant_ethnicity-5        0.895266
# applicant_ethnicity-5           0.568901
# applicant_sex                   0.453300
# co-applicant_ethnicity-4        0.436460
# applicant_race_observed         0.335546
# applicant_ethnicity_observed    0.335381
# applicant_sex_observed          0.332810
# action_taken                    0.242907
# applicant_race-1                0.212066
# co-applicant_ethnicity-1        0.181948
# aus-3                           0.103353
# denial_reason-1                 0.094700
# co-applicant_race-4             0.082986
# co-applicant_race-1             0.071242
# Name: applicant_ethnicity-1, dtype: float64

# %%
race_corr = corr_matrix['applicant_race-1']
race_corr = race_corr.sort_values(ascending=False)
print(ethnicity_corr.head(15))
